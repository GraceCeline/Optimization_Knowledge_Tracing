# %%
import pandas as pd
import os
import glob

def compile_all_kt_results(scenario_ids, output_path='kt_results_summary.csv'):
    """
    Compile results from all KT models (BKT, PFA, DKT) across all scenarios.
    Reads individual CSV files and combines into one summary.
    """
    all_results = []
    
    for scenario_id in scenario_ids:
        for model in ['BKT','TorchBKT', 'PFA', 'DKT', 'DKTplus']:
            filename = f'{model.lower()}_results_scenario_{scenario_id}.csv'
            
            if os.path.exists(filename):
                print(f"Loading {filename}...")
                df = pd.read_csv(filename)
                df['model'] = model
                all_results.append(df)
            else:
                print(f"⚠ Warning: {filename} not found")
    
    if not all_results:
        print("❌ No results found!")
        return None
    
    # Combine all results
    combined_df = pd.concat(all_results, ignore_index=True)
    
    # Reorder columns: scenario, model, then rest
    cols = ['scenario', 'model'] + [col for col in combined_df.columns if col not in ['scenario', 'model']]
    combined_df = combined_df[cols]
    
    # Sort by scenario and model
    combined_df = combined_df.sort_values(['scenario', 'model']).reset_index(drop=True)
    
    # Save to CSV
    combined_df.to_csv(output_path, index=False)
    print(f"\n✓ CSV saved: {os.path.abspath(output_path)}")
    
    # Save as formatted TXT
    txt_path = output_path.replace('.csv', '.txt')
    with open(txt_path, 'w') as f:
        f.write("="*160 + "\n")
        f.write("KNOWLEDGE TRACING MODELS COMPARISON - OPTIMIZATION RESULTS\n")
        f.write("="*160 + "\n\n")
        f.write(combined_df.to_string(index=False))
        f.write("\n\n" + "="*160 + "\n")
        f.write(f"Summary:\n")
        f.write(f"  Scenarios: {sorted(combined_df['scenario'].unique())}\n")
        f.write(f"  Models: {sorted(combined_df['model'].unique())}\n")
        f.write(f"  Total rows: {len(combined_df)}\n")
    
    print(f"✓ TXT saved: {os.path.abspath(txt_path)}\n")
    
    return combined_df

# %%
# ============ RUN COMPILATION ============
scenario_ids = [1, 2, 3, 4, 5, 6, 7, 8]  # Your scenario IDs

final_table = compile_all_kt_results(
    scenario_ids=scenario_ids,
    output_path='kt_results_summary.csv'
)

print("\n" + "="*160)
print("FINAL COMBINED RESULTS")
print("="*160)
print(final_table)
# Out:
# Loading bkt_results_scenario_1.csv...
# Loading torchbkt_results_scenario_1.csv...
# Loading pfa_results_scenario_1.csv...
# Loading dkt_results_scenario_1.csv...
# Loading dktplus_results_scenario_1.csv...
# Loading bkt_results_scenario_2.csv...
# Loading torchbkt_results_scenario_2.csv...
# Loading pfa_results_scenario_2.csv...
# Loading dkt_results_scenario_2.csv...
# Loading dktplus_results_scenario_2.csv...
# Loading bkt_results_scenario_3.csv...
# Loading torchbkt_results_scenario_3.csv...
# Loading pfa_results_scenario_3.csv...
# Loading dkt_results_scenario_3.csv...
# Loading dktplus_results_scenario_3.csv...
# Loading bkt_results_scenario_4.csv...
# Loading torchbkt_results_scenario_4.csv...
# Loading pfa_results_scenario_4.csv...
# Loading dkt_results_scenario_4.csv...
# Loading dktplus_results_scenario_4.csv...
# Loading bkt_results_scenario_5.csv...
# Loading torchbkt_results_scenario_5.csv...
# Loading pfa_results_scenario_5.csv...
# Loading dkt_results_scenario_5.csv...
# Loading dktplus_results_scenario_5.csv...
# Loading bkt_results_scenario_6.csv...
# Loading torchbkt_results_scenario_6.csv...
# Loading pfa_results_scenario_6.csv...
# Loading dkt_results_scenario_6.csv...
# Loading dktplus_results_scenario_6.csv...
# Loading bkt_results_scenario_7.csv...
# Loading torchbkt_results_scenario_7.csv...
# Loading pfa_results_scenario_7.csv...
# Loading dkt_results_scenario_7.csv...
# Loading dktplus_results_scenario_7.csv...
# Loading bkt_results_scenario_8.csv...
# Loading torchbkt_results_scenario_8.csv...
# Loading pfa_results_scenario_8.csv...
# Loading dkt_results_scenario_8.csv...
# Loading dktplus_results_scenario_8.csv...
#
# ✓ CSV saved: /Users/GraceCeline/Bachelorarbeit/Results/kt_results_summary.csv
# ✓ TXT saved: /Users/GraceCeline/Bachelorarbeit/Results/kt_results_summary.txt
#
#
# ================================================================================================================================================================
# FINAL COMBINED RESULTS
# ================================================================================================================================================================
#     scenario     model  p_op_0.0_mean  p_op_0.0_std  p_op_0.33_mean  \
# 0          1       BKT       8.702000      1.590678       10.532000
# 1          1       DKT       9.000000      1.195229       11.346939
# 2          1   DKTplus       8.653061      1.362458       10.571429
# 3          1       PFA       8.640000      1.548666       10.940000
# 4          1  TorchBKT       8.856000      1.516530       11.242000
# 5          2       BKT       6.878000      1.096138        8.402000
# 6          2       DKT       5.387755      0.564831        8.775510
# 7          2   DKTplus       5.244898      0.596190        7.816327
# 8          2       PFA       6.900000      1.035098        8.680000
# 9          2  TorchBKT       6.934000      1.044906        8.524000
# 10         3       BKT      13.272000      2.310128       14.322000
# 11         3       DKT       8.673469      1.376001       10.632653
# 12         3   DKTplus       8.959184      2.020305       11.653061
# 13         3       PFA      11.960000      1.511318       13.260000
# 14         3  TorchBKT      15.020000      2.555124       16.588000
# 15         4       BKT       7.048000      0.987749        8.330000
# 16         4       DKT       5.632653      0.629022       10.163265
# 17         4   DKTplus       5.448980      0.737711        9.326531
# 18         4       PFA       7.540000      1.431568       10.580000
# 19         4  TorchBKT       6.936000      1.004950        8.370000
# 20         5       BKT       6.998000      1.019841        8.574000
# 21         5       DKT       5.591837      0.636264       13.795918
# 22         5   DKTplus       5.510204      0.680761       10.489796
# 23         5       PFA      10.300000      1.555110       13.240000
# 24         5  TorchBKT       6.946000      0.970034        8.382000
# 25         6       BKT      12.790000      2.221660       14.080000
# 26         6       DKT      12.204082      5.118911       14.081633
# 27         6   DKTplus       7.408163      1.171153       11.938776
# 28         6       PFA      12.140000      1.324957       12.980000
# 29         6  TorchBKT      12.118000      1.440912       13.354000
# 30         7       BKT       4.016000      0.424387        7.948000
# 31         7       DKT       4.000000      0.000000       16.693878
# 32         7   DKTplus       4.102041      0.510102       13.958333
# 33         7       PFA       3.960000      0.197949       19.479167
# 34         7  TorchBKT       3.978000      0.146830        7.810000
# 35         8       BKT      12.944000      2.263429       14.500000
# 36         8       DKT      13.142857      2.294625       13.265306
# 37         8   DKTplus       8.897959      1.245741       14.285714
# 38         8       PFA      12.400000      1.795686       14.240000
# 39         8  TorchBKT      13.436000      1.862483       15.228000
#
#     p_op_0.33_std  p_op_0.4_mean  p_op_0.4_std
# 0        2.243891      11.876000      2.944480
# 1        2.607298      11.877551      3.074800
# 2        2.131119      11.489796      3.000850
# 3        2.743527      11.840000      3.291052
# 4        2.702229      12.604000      3.371337
# 5        1.943180       9.198000      2.340460
# 6        1.919453       8.897959      2.674482
# 7        1.822012       9.428571      2.406588
# 8        2.004485       8.540000      1.875840
# 9        2.055693       9.134000      2.398238
# 10       2.613039      15.736000      3.148672
# 11       1.996874      11.693878      2.786294
# 12       2.735195      11.469388      3.021465
# 13       1.893167      14.440000      2.101117
# 14       2.843665      17.696000      3.089770
# 15       1.994255       9.242000      2.554307
# 16       2.605700      14.571429      3.307382
# 17       2.617153      13.000000      3.221025
# 18       2.286518      13.420000      5.091369
# 19       1.918453       9.318000      2.417554
# 20       2.122625       9.246000      2.364035
# 21       3.528193      20.265306      5.065995
# 22       2.283295      13.877551      3.395049
# 23       2.959316      14.200000      2.755329
# 24       2.010014       9.042000      2.393260
# 25       2.347898      15.290000      2.783054
# 26       4.014447      16.816327      5.487178
# 27       2.444451      14.122449      2.333030
# 28       2.494811      14.320000      2.351205
# 29       1.832867      14.170000      2.037007
# 30       0.739181      11.750000      1.090816
# 31       4.961912      21.530612      4.819611
# 32       2.751853      16.142857      2.929733
# 33       3.903024      21.714286      3.444938
# 34       0.659371      11.524000      1.305693
# 35       2.641961      15.590000      3.144149
# 36       3.128379      15.510204      4.940968
# 37       3.195048      15.204082      3.155548
# 38       2.583780      14.620000      2.423440
# 39       2.260583      16.066000      2.646441

# %%
results = pd.read_csv("kt_results_summary.csv")
print(results)
# Out:
#     scenario     model  p_op_0.0_mean  p_op_0.0_std  p_op_0.33_mean  \
# 0          1       BKT       8.702000      1.590678       10.532000
# 1          1       DKT       9.000000      1.195229       11.346939
# 2          1   DKTplus       8.653061      1.362458       10.571429
# 3          1       PFA       8.640000      1.548666       10.940000
# 4          1  TorchBKT       8.856000      1.516530       11.242000
# 5          2       BKT       6.878000      1.096138        8.402000
# 6          2       DKT       5.387755      0.564831        8.775510
# 7          2   DKTplus       5.244898      0.596190        7.816327
# 8          2       PFA       6.900000      1.035098        8.680000
# 9          2  TorchBKT       6.934000      1.044906        8.524000
# 10         3       BKT      13.272000      2.310128       14.322000
# 11         3       DKT       8.673469      1.376001       10.632653
# 12         3   DKTplus       8.959184      2.020305       11.653061
# 13         3       PFA      11.960000      1.511318       13.260000
# 14         3  TorchBKT      15.020000      2.555124       16.588000
# 15         4       BKT       7.048000      0.987749        8.330000
# 16         4       DKT       5.632653      0.629022       10.163265
# 17         4   DKTplus       5.448980      0.737711        9.326531
# 18         4       PFA       7.540000      1.431568       10.580000
# 19         4  TorchBKT       6.936000      1.004950        8.370000
# 20         5       BKT       6.998000      1.019841        8.574000
# 21         5       DKT       5.591837      0.636264       13.795918
# 22         5   DKTplus       5.510204      0.680761       10.489796
# 23         5       PFA      10.300000      1.555110       13.240000
# 24         5  TorchBKT       6.946000      0.970034        8.382000
# 25         6       BKT      12.790000      2.221660       14.080000
# 26         6       DKT      12.204082      5.118911       14.081633
# 27         6   DKTplus       7.408163      1.171153       11.938776
# 28         6       PFA      12.140000      1.324957       12.980000
# 29         6  TorchBKT      12.118000      1.440912       13.354000
# 30         7       BKT       4.016000      0.424387        7.948000
# 31         7       DKT       4.000000      0.000000       16.693878
# 32         7   DKTplus       4.102041      0.510102       13.958333
# 33         7       PFA       3.960000      0.197949       19.479167
# 34         7  TorchBKT       3.978000      0.146830        7.810000
# 35         8       BKT      12.944000      2.263429       14.500000
# 36         8       DKT      13.142857      2.294625       13.265306
# 37         8   DKTplus       8.897959      1.245741       14.285714
# 38         8       PFA      12.400000      1.795686       14.240000
# 39         8  TorchBKT      13.436000      1.862483       15.228000
#
#     p_op_0.33_std  p_op_0.4_mean  p_op_0.4_std
# 0        2.243891      11.876000      2.944480
# 1        2.607298      11.877551      3.074800
# 2        2.131119      11.489796      3.000850
# 3        2.743527      11.840000      3.291052
# 4        2.702229      12.604000      3.371337
# 5        1.943180       9.198000      2.340460
# 6        1.919453       8.897959      2.674482
# 7        1.822012       9.428571      2.406588
# 8        2.004485       8.540000      1.875840
# 9        2.055693       9.134000      2.398238
# 10       2.613039      15.736000      3.148672
# 11       1.996874      11.693878      2.786294
# 12       2.735195      11.469388      3.021465
# 13       1.893167      14.440000      2.101117
# 14       2.843665      17.696000      3.089770
# 15       1.994255       9.242000      2.554307
# 16       2.605700      14.571429      3.307382
# 17       2.617153      13.000000      3.221025
# 18       2.286518      13.420000      5.091369
# 19       1.918453       9.318000      2.417554
# 20       2.122625       9.246000      2.364035
# 21       3.528193      20.265306      5.065995
# 22       2.283295      13.877551      3.395049
# 23       2.959316      14.200000      2.755329
# 24       2.010014       9.042000      2.393260
# 25       2.347898      15.290000      2.783054
# 26       4.014447      16.816327      5.487178
# 27       2.444451      14.122449      2.333030
# 28       2.494811      14.320000      2.351205
# 29       1.832867      14.170000      2.037007
# 30       0.739181      11.750000      1.090816
# 31       4.961912      21.530612      4.819611
# 32       2.751853      16.142857      2.929733
# 33       3.903024      21.714286      3.444938
# 34       0.659371      11.524000      1.305693
# 35       2.641961      15.590000      3.144149
# 36       3.128379      15.510204      4.940968
# 37       3.195048      15.204082      3.155548
# 38       2.583780      14.620000      2.423440
# 39       2.260583      16.066000      2.646441
